# %%
# %matplotlib inline
import scipy as sp
import numpy as np
import matplotlib.pyplot as plt
import pymc
import pymc.Matplot

# %%
def gauss(x, a, b, c):
    return a * sp.exp(-1*(x - b)**2/(2*c)**2)
def gaussians(x, par):
    a1, a2, b1, b2, c1, c2 = par
    arr = gauss(x, a1, b1, c1) + gauss(x, a2, b2, c2)
    return arr

# %%
x = np.arange(0,100,0.1)
#y = gauss(x, 10, 40, 4) + gauss(x, 50, 70, 6) + sp.randn(len(x))*0.7
# data
real_pars = [10, 50, 40, 70, 4, 6]
y = gaussians(x, real_pars) + sp.randn(len(x))*0.7
y_err = np.ones_like(y) * sp.randn(len(x))*0.7
plt.errorbar(x,y, yerr=y_err, ls='None', alpha=0.5)
None

# %%
def make_model(x,y, y_err):
    #bnd = [(5,20), (40,60), (40,60), (60,80), (3,10), (3,10)]
    a1 = pymc.Uniform('a1', 5, 20, value=10)
    a2 = pymc.Uniform('a2', 30, 60, value=50)
    b1 = pymc.Uniform('b1', 30, 60, value=50)
    b2 = pymc.Uniform('b2', 60, 80, value=70)
    c1 = pymc.Uniform('c1', 3., 10, value=5)
    c2 = pymc.Uniform('c2', 3., 10, value=5)
    
    # model
    @pymc.deterministic(plot=False)
    def gauss(x=x, a1=a1, b1=b1, c1=c1, a2=a2, b2=b2, c2=c2):
        gone = a1 * sp.exp(-1*(x - b1)**2/(2*c1)**2) 
        gtwo = a2 * sp.exp(-1*(x - b2)**2/(2*c2)**2)
        return gone + gtwo
    # likelihood
    #~ y = pymc.Normal('y', mu=gauss, tau=1.0/amperr**2, value=f, observed=True)
    y = pymc.Normal('y', mu=gauss, tau=1/y_err**2, value=y, observed=True)
    return locals()

# %%
M = pymc.MCMC(make_model(x,y,y_err))

# %%
M.a1.value
# Out:
# array(10.0)

# %%
M.sample(5e4, burn=50, thin=70)
# Out:
#  [                  0%                  ] 470 of 50000 complete in 0.5 sec
#  [                  1%                  ] 954 of 50000 complete in 1.0 sec
#  [-                 2%                  ] 1453 of 50000 complete in 1.5 sec
#  [-                 3%                  ] 1954 of 50000 complete in 2.0 sec
#  [-                 4%                  ] 2460 of 50000 complete in 2.5 sec
#  [--                5%                  ] 2965 of 50000 complete in 3.0 sec
#  [--                6%                  ] 3458 of 50000 complete in 3.5 sec
#  [---               7%                  ] 3965 of 50000 complete in 4.0 sec
#  [---               8%                  ] 4462 of 50000 complete in 4.5 sec
#  [---               9%                  ] 4968 of 50000 complete in 5.0 sec
#  [----             10%                  ] 5461 of 50000 complete in 5.5 sec
#  [----             11%                  ] 5963 of 50000 complete in 6.0 sec
#  [----             12%                  ] 6462 of 50000 complete in 6.5 sec
#  [-----            13%                  ] 6969 of 50000 complete in 7.0 sec
#  [-----            14%                  ] 7468 of 50000 complete in 7.5 sec
#  [------           15%                  ] 7976 of 50000 complete in 8.0 sec
#  [------           16%                  ] 8484 of 50000 complete in 8.5 sec
#  [------           17%                  ] 8995 of 50000 complete in 9.0 sec
#  [-----------------65%----              ] 32582 of 50000 complete in 32.0 sec
#  [-----------------66%-----             ] 33099 of 50000 complete in 32.5 sec
#  [-----------------67%-----             ] 33615 of 50000 complete in 33.0 sec
#  [-----------------68%-----             ] 34131 of 50000 complete in 33.5 sec
#  [-----------------69%------            ] 34649 of 50000 complete in 34.0 sec
#  [-----------------70%------            ] 35166 of 50000 complete in 34.5 sec
#  [-----------------71%-------           ] 35684 of 50000 complete in 35.0 sec
#  [-----------------72%-------           ] 36199 of 50000 complete in 35.5 sec
#  [-----------------73%-------           ] 36715 of 50000 complete in 36.0 sec
#  [-----------------74%--------          ] 37229 of 50000 complete in 36.5 sec
#  [-----------------75%--------          ] 37744 of 50000 complete in 37.0 sec
#  [-----------------76%---------         ] 38256 of 50000 complete in 37.5 sec
#  [-----------------77%---------         ] 38769 of 50000 complete in 38.0 sec
#  [-----------------78%---------         ] 39285 of 50000 complete in 38.5 sec
#  [-----------------79%----------        ] 39799 of 50000 complete in 39.0 sec
#  [-----------------80%----------        ] 40312 of 50000 complete in 39.5 sec
#  [-----------------81%-----------       ] 40829 of 50000 complete in 40.0 sec
#  [-----------------82%-----------       ] 41348 of 50000 complete in 40.5 sec
#  [-----------------83%-----------       ] 41868 of 50000 complete in 41.0 sec
#  [-----------------84%------------      ] 42377 of 50000 complete in 41.5 sec
#  [-----------------85%------------      ] 42887 of 50000 complete in 42.0 sec
#  [-----------------86%------------      ] 43405 of 50000 complete in 42.5 sec
#  [-----------------87%-------------     ] 43922 of 50000 complete in 43.0 sec
#  [-----------------88%-------------     ] 44439 of 50000 complete in 43.5 sec
#  [-----------------89%--------------    ] 44956 of 50000 complete in 44.0 sec
#  [-----------------90%--------------    ] 45470 of 50000 complete in 44.5 sec
#  [-----------------91%--------------    ] 45986 of 50000 complete in 45.0 sec
#  [-----------------93%---------------   ] 46502 of 50000 complete in 45.5 sec
#  [-----------------94%---------------   ] 47009 of 50000 complete in 46.0 sec
#  [-----------------95%----------------  ] 47525 of 50000 complete in 46.5 sec
#  [-----------------96%----------------  ] 48040 of 50000 complete in 47.0 sec
#  [-----------------97%----------------  ] 48554 of 50000 complete in 47.5 sec
#  [-----------------98%----------------- ] 49067 of 50000 complete in 48.0 sec
#  [-----------------99%----------------- ] 49584 of 50000 complete in 48.5 sec
#  [-----------------100%-----------------] 50000 of 50000 complete in 49.0 sec

# %%
pymc.Matplot.plot(M); None
# Out:
# Plotting b2
# Plotting
#  a1
# Plotting
#  c2
# Plotting
#  b1
# Plotting
#  a2
# Plotting
#  c1

# %%
a1_f = M.stats()['a1']['mean']
a1_f_sig = M.stats()['a1']['standard deviation']
b1_f = M.stats()['b1']['mean']
b1_f_sig = M.stats()['b1']['standard deviation']

# %%
print a1_f, a1_f_sig
print b1_f, b1_f_sig
# Out:
# 9.99584103676 0.441851096973
# 39.7584798331 0.224789026059

# %%
real_pars
# Out:
# [10, 50, 40, 70, 4, 6]
